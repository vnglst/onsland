# %%
import pandas as pd

# %%
# Load the CSV file
file_path = 'WENR-landgebruik.csv'
data = pd.read_csv(file_path, delimiter=';', header=5)
data.columns = ['LGN-Klassen', 'LGN2018', 'LGN2021', "Verschil", "Categorie"]
data.head()

data
# Out:
#                                           LGN-Klassen  LGN2018  LGN2021  \
# 0                                6 - Overige gewassen   130266   139234
# 1                                    8 - Glastuinbouw    14017    12944
# 2                                     9 - Boomgaarden     3191     2898
# 3                                    10 - Bloembollen    31995    30563
# 4                                 61 - Boomkwekerijen    20874    19432
# 5                                62 - Fruitkwekerijen    25216    24656
# 6                      26 - Bebouwing in buitengebied    20181    24219
# 7            27 - Overig grondgebruik in buitengebied    81015    96309
# 8      45 - Natuurlijk beheerde agrarische graslanden        0   111078
# 9                                        11 - Loofbos   108875   171659
# 10                                      12 - Naaldbos   175433   141113
# 11                                    16 - Zoet water   369135   373844
# 12                                    17 - Zout water   441789  1170824
# 13           18 - Bebouwing in primair bebouwd gebied    81962    91932
# 14         19 - Bebouwing in secundair bebouwd gebied     7867     9655
# 15          24 - Kale grond in primair bebouwd gebied     1227        0
# 16                 20 - Bos in primair bebouwd gebied    13867    13670
# 17               22 - Bos in secundair bebouwd gebied    24052    29331
# 18                23 - Gras in primair bebouwd gebied   270323   248501
# 19              28 - Gras in secundair bebouwd gebied    96243    99452
# 20                      25 - Hoofdwegen en spoorwegen   212393        0
# 21     251 - Hoofdinfrastructuur en spoorbaanlichamen        0   122643
# 22  252 - Halfverharde wegen, infrastructuur langz...        0    63423
# 23                                 253 - Smalle wegen        0     6407
# 24                                   29 - Zonneparken        0     2021
# 25                                      30 - Kwelders    11355    12109
# 26                       31 - Open zand in kustgebied    10154    10413
# 27           32 - Duinen met een lage vegetatie (<1m)     2042     2615
# 28           33 - Duinen met een hoge vegetatie (>1m)     2947     2613
# 29                                     34 - Duinheide      239      628
# 30                            46 - Gras in kustgebied    19573    19050
# 31               35 - Open stuifzand en/of rivierzand     1584     3239
# 32                                         36 - Heide    12226    16914
# 33                         37 - Matig vergraste heide    16222    14481
# 34                         38 - Sterk vergraste heide     9206     4025
# 35                                      39 - Hoogveen     6730     6966
# 36     321 - Struikvegetatie in hoogveengebied (laag)      279      391
# 37     331 - Struikvegetatie in hoogveengebied (hoog)      726      489
# 38                         40 - Bos in hoogveengebied     1685     2835
# 39                       41 - Overige moerasvegetatie    30766    29864
# 40                           43 - Bos in moerasgebied     3100     3031
# 41                              45 - Natuurgraslanden   134131        0
# 42                                   47 - Overig gras    23084    48872
# 43       322 - Struikvegetatie in moerasgebied (laag)     1349     4337
# 44       333 - Struikvegetatie in moerasgebied (hoog)     2261     3692
#
#     Verschil       Categorie
# 0       8968        Landbouw
# 1      -1072        Landbouw
# 2       -293        Landbouw
# 3      -1433        Landbouw
# 4      -1441        Landbouw
# 5       -560        Landbouw
# 6       4038  Bebouwd gebied
# 7      15294  Bebouwd gebied
# 8     111078          Natuur
# 9      62785          Natuur
# 10    -34320          Natuur
# 11      4709     Binnenwater
# 12    729034          Natuur
# 13      9969  Bebouwd gebied
# 14      1787  Bebouwd gebied
# 15     -1227  Bebouwd gebied
# 16      -197  Bebouwd gebied
# 17      5280  Bebouwd gebied
# 18    -21823  Bebouwd gebied
# 19      3209  Bebouwd gebied
# 20   -212393  Infrastructuur
# 21    122643  Infrastructuur
# 22     63423  Infrastructuur
# 23      6407  Infrastructuur
# 24      2021  Infrastructuur
# 25       754          Natuur
# 26       259          Natuur
# 27       573          Natuur
# 28      -334          Natuur
# 29       389          Natuur
# 30      -524          Natuur
# 31      1655          Natuur
# 32      4689          Natuur
# 33     -1741          Natuur
# 34     -5181          Natuur
# 35       236          Natuur
# 36       112          Natuur
# 37      -237          Natuur
# 38      1150          Natuur
# 39      -902          Natuur
# 40       -69          Natuur
# 41   -134131          Natuur
# 42     25788          Natuur
# 43      2988          Natuur
# 44      1431          Natuur

# %%
# Keep only the columns LGN-Klassen, LGN2021 and Category
data = data[['LGN-Klassen', 'LGN2021', 'Categorie']]

# Remove rows that are 0
data = data[data['LGN2021'] != 0]

# Drop the row for Zout water
data = data[data['LGN-Klassen'] != 'Zout water']

data
# Out:
#                                           LGN-Klassen  LGN2021       Categorie
# 0                                6 - Overige gewassen   139234        Landbouw
# 1                                    8 - Glastuinbouw    12944        Landbouw
# 2                                     9 - Boomgaarden     2898        Landbouw
# 3                                    10 - Bloembollen    30563        Landbouw
# 4                                 61 - Boomkwekerijen    19432        Landbouw
# 5                                62 - Fruitkwekerijen    24656        Landbouw
# 6                      26 - Bebouwing in buitengebied    24219  Bebouwd gebied
# 7            27 - Overig grondgebruik in buitengebied    96309  Bebouwd gebied
# 8      45 - Natuurlijk beheerde agrarische graslanden   111078          Natuur
# 9                                        11 - Loofbos   171659          Natuur
# 10                                      12 - Naaldbos   141113          Natuur
# 11                                    16 - Zoet water   373844     Binnenwater
# 12                                    17 - Zout water  1170824          Natuur
# 13           18 - Bebouwing in primair bebouwd gebied    91932  Bebouwd gebied
# 14         19 - Bebouwing in secundair bebouwd gebied     9655  Bebouwd gebied
# 16                 20 - Bos in primair bebouwd gebied    13670  Bebouwd gebied
# 17               22 - Bos in secundair bebouwd gebied    29331  Bebouwd gebied
# 18                23 - Gras in primair bebouwd gebied   248501  Bebouwd gebied
# 19              28 - Gras in secundair bebouwd gebied    99452  Bebouwd gebied
# 21     251 - Hoofdinfrastructuur en spoorbaanlichamen   122643  Infrastructuur
# 22  252 - Halfverharde wegen, infrastructuur langz...    63423  Infrastructuur
# 23                                 253 - Smalle wegen     6407  Infrastructuur
# 24                                   29 - Zonneparken     2021  Infrastructuur
# 25                                      30 - Kwelders    12109          Natuur
# 26                       31 - Open zand in kustgebied    10413          Natuur
# 27           32 - Duinen met een lage vegetatie (<1m)     2615          Natuur
# 28           33 - Duinen met een hoge vegetatie (>1m)     2613          Natuur
# 29                                     34 - Duinheide      628          Natuur
# 30                            46 - Gras in kustgebied    19050          Natuur
# 31               35 - Open stuifzand en/of rivierzand     3239          Natuur
# 32                                         36 - Heide    16914          Natuur
# 33                         37 - Matig vergraste heide    14481          Natuur
# 34                         38 - Sterk vergraste heide     4025          Natuur
# 35                                      39 - Hoogveen     6966          Natuur
# 36     321 - Struikvegetatie in hoogveengebied (laag)      391          Natuur
# 37     331 - Struikvegetatie in hoogveengebied (hoog)      489          Natuur
# 38                         40 - Bos in hoogveengebied     2835          Natuur
# 39                       41 - Overige moerasvegetatie    29864          Natuur
# 40                           43 - Bos in moerasgebied     3031          Natuur
# 42                                   47 - Overig gras    48872          Natuur
# 43       322 - Struikvegetatie in moerasgebied (laag)     4337          Natuur
# 44       333 - Struikvegetatie in moerasgebied (hoog)     3692          Natuur

# %%
# Sum all the areas
total_area = data['LGN2021'].sum()

print(f'Total area: {total_area} ha')

# Calculate the percentage of each class
data['Percentage'] = data['LGN2021'] / total_area

data
# Out:
# Total area: 3192372 ha
#                                           LGN-Klassen  LGN2021  \
# 0                                6 - Overige gewassen   139234
# 1                                    8 - Glastuinbouw    12944
# 2                                     9 - Boomgaarden     2898
# 3                                    10 - Bloembollen    30563
# 4                                 61 - Boomkwekerijen    19432
# 5                                62 - Fruitkwekerijen    24656
# 6                      26 - Bebouwing in buitengebied    24219
# 7            27 - Overig grondgebruik in buitengebied    96309
# 8      45 - Natuurlijk beheerde agrarische graslanden   111078
# 9                                        11 - Loofbos   171659
# 10                                      12 - Naaldbos   141113
# 11                                    16 - Zoet water   373844
# 12                                    17 - Zout water  1170824
# 13           18 - Bebouwing in primair bebouwd gebied    91932
# 14         19 - Bebouwing in secundair bebouwd gebied     9655
# 16                 20 - Bos in primair bebouwd gebied    13670
# 17               22 - Bos in secundair bebouwd gebied    29331
# 18                23 - Gras in primair bebouwd gebied   248501
# 19              28 - Gras in secundair bebouwd gebied    99452
# 21     251 - Hoofdinfrastructuur en spoorbaanlichamen   122643
# 22  252 - Halfverharde wegen, infrastructuur langz...    63423
# 23                                 253 - Smalle wegen     6407
# 24                                   29 - Zonneparken     2021
# 25                                      30 - Kwelders    12109
# 26                       31 - Open zand in kustgebied    10413
# 27           32 - Duinen met een lage vegetatie (<1m)     2615
# 28           33 - Duinen met een hoge vegetatie (>1m)     2613
# 29                                     34 - Duinheide      628
# 30                            46 - Gras in kustgebied    19050
# 31               35 - Open stuifzand en/of rivierzand     3239
# 32                                         36 - Heide    16914
# 33                         37 - Matig vergraste heide    14481
# 34                         38 - Sterk vergraste heide     4025
# 35                                      39 - Hoogveen     6966
# 36     321 - Struikvegetatie in hoogveengebied (laag)      391
# 37     331 - Struikvegetatie in hoogveengebied (hoog)      489
# 38                         40 - Bos in hoogveengebied     2835
# 39                       41 - Overige moerasvegetatie    29864
# 40                           43 - Bos in moerasgebied     3031
# 42                                   47 - Overig gras    48872
# 43       322 - Struikvegetatie in moerasgebied (laag)     4337
# 44       333 - Struikvegetatie in moerasgebied (hoog)     3692
#
#          Categorie  Percentage
# 0         Landbouw    0.043615
# 1         Landbouw    0.004055
# 2         Landbouw    0.000908
# 3         Landbouw    0.009574
# 4         Landbouw    0.006087
# 5         Landbouw    0.007723
# 6   Bebouwd gebied    0.007587
# 7   Bebouwd gebied    0.030168
# 8           Natuur    0.034795
# 9           Natuur    0.053772
# 10          Natuur    0.044203
# 11     Binnenwater    0.117105
# 12          Natuur    0.366757
# 13  Bebouwd gebied    0.028797
# 14  Bebouwd gebied    0.003024
# 16  Bebouwd gebied    0.004282
# 17  Bebouwd gebied    0.009188
# 18  Bebouwd gebied    0.077842
# 19  Bebouwd gebied    0.031153
# 21  Infrastructuur    0.038418
# 22  Infrastructuur    0.019867
# 23  Infrastructuur    0.002007
# 24  Infrastructuur    0.000633
# 25          Natuur    0.003793
# 26          Natuur    0.003262
# 27          Natuur    0.000819
# 28          Natuur    0.000819
# 29          Natuur    0.000197
# 30          Natuur    0.005967
# 31          Natuur    0.001015
# 32          Natuur    0.005298
# 33          Natuur    0.004536
# 34          Natuur    0.001261
# 35          Natuur    0.002182
# 36          Natuur    0.000122
# 37          Natuur    0.000153
# 38          Natuur    0.000888
# 39          Natuur    0.009355
# 40          Natuur    0.000949
# 42          Natuur    0.015309
# 43          Natuur    0.001359
# 44          Natuur    0.001157

# %%
# Sanity check, the sum of all percentages should be 1
print(data['Percentage'].sum())
# Out:
# 0.9999999999999999

# %%
# Group by category and sum the areas
data_grouped = data.groupby('Categorie').sum()

data_grouped
# Out:
#                                                       LGN-Klassen  LGN2021  \
# Categorie
# Bebouwd gebied  26 - Bebouwing in buitengebied27 - Overig gron...   613069
# Binnenwater                                       16 - Zoet water   373844
# Infrastructuur  251 - Hoofdinfrastructuur en spoorbaanlichamen...   194494
# Landbouw        6 - Overige gewassen8 - Glastuinbouw9 - Boomga...   229727
# Natuur          45 - Natuurlijk beheerde agrarische graslanden...  1781238
#
#                 Percentage
# Categorie
# Bebouwd gebied    0.192042
# Binnenwater       0.117105
# Infrastructuur    0.060925
# Landbouw          0.071961
# Natuur            0.557967

# %%
# Sanity check, the sum of all percentages should be 1
print(data_grouped['Percentage'].sum())
# Out:
# 1.0
